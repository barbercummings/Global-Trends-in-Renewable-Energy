# %%
import pandas as pd
import random
import numpy as np

# %%
file = "Project-1/college_ed.csv"

# %%
Ed = pd.read_csv("college_ed.csv")

Ed.groupby(['Country']).head()

Ed = Ed.drop(Ed[(Ed.Year < 2000) | (Ed.Year > 2015)].index)

Ed[Ed.Code != '']
Ed[Ed.Country != 'World']
# Out:
#           Country Code  Year  College Enrolment ratio
# 14    Afghanistan  AFG  2003                 1.256840
# 15    Afghanistan  AFG  2004                 1.256030
# 16    Afghanistan  AFG  2009                 3.903390
# 17    Afghanistan  AFG  2011                 3.755980
# 18    Afghanistan  AFG  2014                 8.662800
# 40        Albania  ALB  2000                15.603730
# 41        Albania  ALB  2001                15.974960
# 42        Albania  ALB  2002                16.431709
# 43        Albania  ALB  2003                16.805559
# 44        Albania  ALB  2004                20.055540
# 45        Albania  ALB  2005                23.311100
# 46        Albania  ALB  2006                26.620440
# 47        Albania  ALB  2007                30.653669
# 48        Albania  ALB  2008                32.077801
# 49        Albania  ALB  2009                33.400749
# 50        Albania  ALB  2010                44.540649
# ...

# %%
print('Shape', Ed.shape)
print('-------------------------')
print('Number of rows', len(Ed))
print('-------------------------')
print('Column headers', Ed.columns)
print('-------------------------')
print('Data types', Ed.dtypes)
print('-------------------------')
print('Index', Ed.index)
print('-------------------------')
# Out:
# Shape (2277, 4)
# -------------------------
# Number of rows 2277
# -------------------------
# Column headers Index(['Country', 'Code', 'Year', 'College Enrolment ratio'], dtype='object')
# -------------------------
# Data types Country                     object
# Code                        object
# Year                         int64
# College Enrolment ratio    float64
# dtype: object
# -------------------------
# Index Int64Index([  14,   15,   16,   17,   18,   40,   41,   42,   43,   44,
#             ...
#             6206, 6207, 6208, 6209, 6210, 6211, 6250, 6251, 6252, 6253],
#            dtype='int64', length=2277)
# -------------------------

# %%
Ed.to_csv("ed_output.csv")
