# %%
import pandas as pd
import random
import numpy as np
import matplotlib as plt

# %%
file = "Project-1/ed_fund.csv"

# %%
df = pd.read_csv("ed_fund.csv")
df.head()
# Out:
#   Country Name Country Code  \
# 0        Aruba          ABW
# 1  Afghanistan          AFG
# 2       Angola          AGO
# 3      Albania          ALB
# 4      Andorra          AND
#
#                                       Indicator Name     Indicator Code  1960  \
# 0  Government expenditure on education, total (% ...  SE.XPD.TOTL.GB.ZS   NaN
# 1  Government expenditure on education, total (% ...  SE.XPD.TOTL.GB.ZS   NaN
# 2  Government expenditure on education, total (% ...  SE.XPD.TOTL.GB.ZS   NaN
# 3  Government expenditure on education, total (% ...  SE.XPD.TOTL.GB.ZS   NaN
# 4  Government expenditure on education, total (% ...  SE.XPD.TOTL.GB.ZS   NaN
#
#    1961  1962  1963  1964  1965  ...   2009      2010       2011     2012  \
# 0   NaN   NaN   NaN   NaN   NaN  ...    NaN       NaN        NaN      NaN
# 1   NaN   NaN   NaN   NaN   NaN  ...    NaN  17.06756  16.048429  10.3568
# 2   NaN   NaN   NaN   NaN   NaN  ...    NaN   8.68477        NaN      NaN
# ...

# %%
clean_df = df[["Country Name", "Country Code", "2000", "2001", "2002", "2003", "2004", "2005", "2006", "2007", "2008", "2009", "2010"]].head()

# %%
clean_df
# Out:
#   Country Name Country Code      2000      2001     2002     2003      2004  \
# 0        Aruba          ABW       NaN       NaN      NaN      NaN       NaN
# 1  Afghanistan          AFG       NaN       NaN      NaN      NaN       NaN
# 2       Angola          AGO   5.25508       NaN      NaN      NaN       NaN
# 3      Albania          ALB  10.13703  10.58193  9.88692  10.5736  10.70316
# 4      Andorra          AND       NaN       NaN      NaN      NaN       NaN
#
#        2005      2006      2007  2008  2009      2010
# 0       NaN       NaN       NaN   NaN   NaN       NaN
# 1       NaN       NaN       NaN   NaN   NaN  17.06756
# 2   7.99235   7.45479       NaN   NaN   NaN   8.68477
# 3  11.35797  10.93295  11.17719   NaN   NaN       NaN
# 4       NaN       NaN       NaN   NaN   NaN       NaN

# %%
print('Shape', clean_df.shape)
print('-------------------------')
print('Number of rows', len(clean_df))
print('-------------------------')
print('Column headers', clean_df.columns)
print('-------------------------')
print('Data types', clean_df.dtypes)
print('-------------------------')
print('Index', clean_df.index)
print('-------------------------')
# Out:
# Shape (5, 13)
# -------------------------
# Number of rows 5
# -------------------------
# Column headers Index(['Country Name', 'Country Code', '2000', '2001', '2002', '2003', '2004',
#        '2005', '2006', '2007', '2008', '2009', '2010'],
#       dtype='object')
# -------------------------
# Data types Country Name     object
# Country Code     object
# 2000            float64
# 2001            float64
# 2002            float64
# 2003            float64
# 2004            float64
# 2005            float64
# 2006            float64
# 2007            float64
# 2008            float64
# 2009            float64
# 2010            float64
# dtype: object
# -------------------------
# Index RangeIndex(start=0, stop=5, step=1)
# -------------------------

# %%
clean_df.dropna()
clean_df
# Out:
#   Country Name Country Code      2000      2001     2002     2003      2004  \
# 0        Aruba          ABW       NaN       NaN      NaN      NaN       NaN
# 1  Afghanistan          AFG       NaN       NaN      NaN      NaN       NaN
# 2       Angola          AGO   5.25508       NaN      NaN      NaN       NaN
# 3      Albania          ALB  10.13703  10.58193  9.88692  10.5736  10.70316
# 4      Andorra          AND       NaN       NaN      NaN      NaN       NaN
#
#        2005      2006      2007  2008  2009      2010
# 0       NaN       NaN       NaN   NaN   NaN       NaN
# 1       NaN       NaN       NaN   NaN   NaN  17.06756
# 2   7.99235   7.45479       NaN   NaN   NaN   8.68477
# 3  11.35797  10.93295  11.17719   NaN   NaN       NaN
# 4       NaN       NaN       NaN   NaN   NaN       NaN

# %%
df.count()
# Out:
# Country Name      264
# Country Code      264
# Indicator Name    264
# Indicator Code    264
# 1960                0
# 1961                0
# 1962                0
# 1963                0
# 1964                0
# 1965                0
# 1966                0
# 1967                0
# 1968                0
# 1969                0
# 1970                0
# 1971                0
# 1972                0
# 1973                0
# 1974                0
# 1975                0
# 1976                0
# 1977                0
# 1978                0
# 1979                0
# 1980                4
# 1981               18
# 1982               19
# 1983               18
# 1984               20
# 1985               21
#                  ...
# 1989               27
# 1990               26
# 1991               35
# 1992               32
# 1993               43
# 1994               49
# 1995               55
# 1996               70
# 1997               33
# 1998               81
# ...
